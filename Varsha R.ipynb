# %%
##IMPORTING DATASET
from keras.datasets import mnist
 
data = mnist.load_data()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11493376/11490434 [==============================] - 0s 0us/step

# %%
 (X_train,y_train),(X_test, y_test)=data

# %%
 X_train[0].shape
# Out:
# (28, 28)

# %%
X_train=X_train.reshape((X_train.shape[0],28*28)).astype('float32')
X_test=X_test.reshape((X_test.shape[0],28*28)).astype('float32')

# %%
X_train =X_train/255
X_test=X_test/255

# %%
from keras.models import Sequential
from keras.layers import Dense

# %%
from keras.utils import np_utils
 
print(y_test.shape)
 
y_train= np_utils.to_categorical(y_train) 
y_test= np_utils.to_categorical(y_test)
 
num_classes = y_test.shape[1] 
print(num_classes)
# Out:
# (10000,)
# 10

# %%
model= Sequential()
model.add(Dense(32,input_dim=28*28,activation='relu'))
model.add(Dense(64,activation='relu'))
model.add(Dense(10,activation='softmax'))

# %%
 model.compile(loss='categorical_crossentropy',optimizer='adam',metrics=['accuracy'])

# %%
 model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                (None, 32)                25120
# _________________________________________________________________
# dense_1 (Dense)              (None, 64)                2112
# _________________________________________________________________
# dense_2 (Dense)              (None, 10)                650
# =================================================================
# Total params: 27,882
# Trainable params: 27,882
# Non-trainable params: 0
# _________________________________________________________________

# %%
 model.fit(X_train, y_train ,validation_split=0.2, epochs=10, batch_size=100)
# Out:
# Epoch 1/10
# 480/480 [==============================] - 2s 3ms/step - loss: 2.0206 - accuracy: 0.3367 - val_loss: 0.9505 - val_accuracy: 0.7297
# Epoch 2/10
# 480/480 [==============================] - 1s 2ms/step - loss: 0.8670 - accuracy: 0.7320 - val_loss: 0.6476 - val_accuracy: 0.8096
# Epoch 3/10
# 480/480 [==============================] - 1s 2ms/step - loss: 0.6412 - accuracy: 0.8043 - val_loss: 0.5309 - val_accuracy: 0.8447
# Epoch 4/10
# 480/480 [==============================] - 1s 2ms/step - loss: 0.5249 - accuracy: 0.8438 - val_loss: 0.4482 - val_accuracy: 0.8732
# Epoch 5/10
# 480/480 [==============================] - 1s 2ms/step - loss: 0.4582 - accuracy: 0.8669 - val_loss: 0.4041 - val_accuracy: 0.8855
# Epoch 6/10
# 480/480 [==============================] - 1s 2ms/step - loss: 0.4133 - accuracy: 0.8809 - val_loss: 0.3763 - val_accuracy: 0.8921
# Epoch 7/10
# 480/480 [==============================] - 1s 2ms/step - loss: 0.3926 - accuracy: 0.8856 - val_loss: 0.3556 - val_accuracy: 0.8972
# Epoch 8/10
# 480/480 [==============================] - 1s 2ms/step - loss: 0.3598 - accuracy: 0.8954 - val_loss: 0.3399 - val_accuracy: 0.9018
# Epoch 9/10
# 480/480 [==============================] - 1s 2ms/step - loss: 0.3556 - accuracy: 0.8988 - val_loss: 0.3261 - val_accuracy: 0.9060
# Epoch 10/10
# 480/480 [==============================] - 1s 2ms/step - loss: 0.3377 - accuracy: 0.9021 - val_loss: 0.3147 - val_accuracy: 0.9096

# %%
 
scores =model.evaluate(X_test,y_test)
print(scores)
# Out:
# 313/313 [==============================] - 1s 1ms/step - loss: 0.3203 - accuracy: 0.9068
# [0.32028231024742126, 0.9067999720573425]

# %%
 predictions = model.predict(X_test)
